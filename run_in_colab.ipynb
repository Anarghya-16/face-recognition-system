# %% [markdown]
# # Face Recognition Identification System — Colab runnerRun these cells top to bottom on free Google Colab (Runtime -> Change runtime type -> T4 GPU is optional; CPU works).

# %% [markdown]
# ## 1. Get the code

# %%
# !git clone https://github.com/<your-username>/face-recognition-system.git%cd face-recognition-system

# %% [markdown]
# ## 2. Install dependencies (~2 min)

# %%
# !pip install -q insightface onnxruntime opencv-python-headless "numpy<2" matplotlib scikit-learn Pillow

# %% [markdown]
# ## 3. Build a free dataset (LFW), or upload your own images instead

# %%
# !python prepare_lfw.py --known 20 --unknown 20 --min-faces 5

# %% [markdown]
# Alternatively, upload your own photos and arrange them as `data/enroll/<person_name>/*.jpg`:

# %%
# from google.colab import files# uploaded = files.upload()

# %% [markdown]
# ## 4. Enrol

# %%
# !python enroll.py --data data/enroll --gallery models/gallery.npz

# %% [markdown]
# ## 5. Evaluate (this produces the numbers for the README)

# %%
# !python evaluate.py --data data/enroll --unknown-data data/unknown --gallery-per-id 2 --threshold 0.35 --out results

# %%
from IPython.display import Image, displaydisplay(Image('results/score_distributions.png'))display(Image('results/threshold_sweep.png'))

# %% [markdown]
# ## 6. Identify a query image

# %%
# !python identify.py --folder data/unknown --gallery models/gallery.npz --threshold 0.35 --json results/predictions.json

# %% [markdown]
# ## 7. Push results back to GitHub

# %%
# !git config --global user.email "you@example.com"# !git config --global user.name  "Your Name"# !git add results README.md && !git commit -m "Add evaluation results" && !git push
